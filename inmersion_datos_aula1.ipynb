# %% [markdown]
# <a href="https://colab.research.google.com/github/Sublian/Inmersion_datos/blob/main/inmersion_datos_aula1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bienvenido al primer encuentro de inmersion de datos

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

inmuebles = pd.read_csv('/content/drive/MyDrive/inmersion_datos/inmuebles_bogota.csv')
inmuebles.head()
# Out:
#           Tipo                                 Descripcion  Habitaciones  \
# 0  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 1         Casa                   Casa en venta en Castilla             4
# 2  Apartamento     Apartamento en venta en Chico Reservado             3
# 3  Apartamento             Apartamento en venta en Usaquén             3
# 4  Apartamento         Apartamento en venta en Bella Suiza             2
#
#    Baños  Área              Barrio                                    UPZ  \
# 0      2    70  Zona Noroccidental     CHAPINERO: Pardo Rubio + Chapinero
# 1      3   170            Castilla            KENNEDY: Castilla + Bavaria
# 2      3   144     Chico Reservado     CHAPINERO: Chicó Lago + El Refugio
# 3      2   154             Usaquén                                Usaquén
# 4      3   128         Bella Suiza  USAQUÉN: Country Club + Santa Bárbara
#
#              Valor
# 0    $ 360.000.000
# 1    $ 670.000.000
# 2  $ 1.120.000.000
# ...

# %%
inmuebles.shape
#muestra la cantidad de registros y la cantidad de columnas o atributos
# Out:
# (9520, 8)

# %%
inmuebles.columns
#muestra la cantidad de columnas
# Out:
# Index(['Tipo', 'Descripcion', 'Habitaciones', 'Baños', 'Área', 'Barrio', 'UPZ',
#        'Valor'],
#       dtype='object')

# %%
columnas ={'Baños': 'Banos', 'Área': 'Area'}
#rename sirve para hacer un cambio de nombre de columnas, se utilizo un diccionario
inmuebles = inmuebles.rename(columns=columnas)
#sample sirve para obtener una muestra
inmuebles.sample(10)
# Out:
#              Tipo                                 Descripcion  Habitaciones  \
# 7205         Casa                    Casa en venta en Kennedy             3
# 8954  Apartamento         Apartamento en venta en Santa Paula             2
# 8793  Apartamento                Apartamento en venta en Bosa             3
# 2839  Apartamento  Apartamento en venta en Zona Noroccidental             3
# 4895  Apartamento      Apartamento en venta en Barrios Unidos             3
# 9325  Apartamento      Apartamento en venta en Nueva Zelandia             3
# 1369         Casa                       Casa en venta en Suba             4
# 7988         Casa                    Casa en venta en Kennedy             4
# 1883  Apartamento             Apartamento en venta en Usaquén             2
# 1749  Apartamento             Apartamento en venta en Usaquén             2
#
#       Banos  Area              Barrio  \
# 7205      2    86             Kennedy
# 8954      3    85         Santa Paula
# ...

# %%
#muestra informacion sobre el data set. columnas, nombre de columnas
#conteo de no nulos y tipo de variable
#upz es sobre los distritos de bogota o Unidades de Planeamiento Zonal o UPZ
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %%
inmuebles.iloc[300]
# Out:
# Tipo                                Apartamento
# Descripcion     Apartamento en venta en Kennedy
# Habitaciones                                  2
# Banos                                         1
# Area                                         42
# Barrio                                  Kennedy
# UPZ                             Kennedy Central
# Valor                             $ 116.100.000
# Name: 300, dtype: object

# %%
inmuebles.iloc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000

# %%
inmuebles.loc[300:305]
# Out:
#             Tipo                          Descripcion  Habitaciones  Banos  \
# 300  Apartamento      Apartamento en venta en Kennedy             2      1
# 301  Apartamento  Apartamento en venta en Chico Norte             2      2
# 302  Apartamento      Apartamento en venta en Kennedy             3      2
# 303  Apartamento      Apartamento en venta en Kennedy             3      2
# 304  Apartamento     Apartamento en venta en Cedritos             4      4
# 305  Apartamento     Apartamento en venta en Cedritos             3      3
#
#      Area       Barrio                                 UPZ          Valor
# 300    42      Kennedy                     Kennedy Central  $ 116.100.000
# 301    95  Chico Norte  CHAPINERO: Chicó Lago + El Refugio  $ 980.000.000
# 302    54      Kennedy                     Kennedy Central  $ 237.000.000
# 303    67      Kennedy                     Kennedy Central  $ 320.000.000
# 304   132     Cedritos                             Usaquén  $ 530.000.000
# ...

# %%
inmuebles['Valor'][300]
# Out:
# '$ 116.100.000'

# %%
inmuebles['Valor'][300:305]
# Out:
# 300    $ 116.100.000
# 301    $ 980.000.000
# 302    $ 237.000.000
# 303    $ 320.000.000
# 304    $ 530.000.000
# Name: Valor, dtype: object

# %%
(inmuebles.Barrio=='Chico Reservado')
# Out:
# 0       False
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 9515    False
# 9516    False
# 9517    False
# 9518    False
# 9519    False
# Name: Barrio, Length: 9520, dtype: bool

# %%
#como el valor verdadero es True o 1 al sumar encontramos la cantidad de
#registros que complacen la condicion
sum((inmuebles.Barrio=='Chico Reservado'))
# Out:
# 225

# %%
#de esta forma obtenermos una consulta especifica por barrio dado
inmuebles_chico =(inmuebles.Barrio=='Chico Reservado')
chico_reservado = inmuebles[inmuebles_chico]
chico_reservado
# Out:
#              Tipo                              Descripcion  Habitaciones  \
# 2     Apartamento  Apartamento en venta en Chico Reservado             3
# 39    Apartamento  Apartamento en venta en Chico Reservado             1
# 72    Apartamento  Apartamento en venta en Chico Reservado             1
# 126   Apartamento  Apartamento en venta en Chico Reservado             3
# 143   Apartamento  Apartamento en venta en Chico Reservado             2
# ...           ...                                      ...           ...
# 9299  Apartamento  Apartamento en venta en Chico Reservado             3
# 9335  Apartamento  Apartamento en venta en Chico Reservado             3
# 9341  Apartamento  Apartamento en venta en Chico Reservado             2
# 9472  Apartamento  Apartamento en venta en Chico Reservado             3
# 9506  Apartamento  Apartamento en venta en Chico Reservado             3
#
#       Banos  Area           Barrio                                 UPZ  \
# ...

# %%
chico_reservado.Area.mean()
# Out:
# 142.78666666666666

# %%
inmuebles.Area.mean()
# Out:
# 146.66470588235293

# %%
#obtenemos la cantidad de inmuebles por barrios con el conteo total de barrios
#es decir la cantidad que existen en cada barrio
inmuebles.Barrio.value_counts()
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64

# %%
#conteo de nombre de barrio
len(inmuebles.Barrio.value_counts())
# Out:
# 149

# %%
#conteo por UPZ
len(inmuebles.UPZ.value_counts())
# Out:
# 63

# %%
#graficando
inmuebles_barrio = inmuebles.Barrio.value_counts()
inmuebles_barrio.plot.bar()
# Out:
# <Axes: >

# %%
inmuebles_barrio.head(20).plot.bar()
# Out:
# <Axes: >

# %% [markdown]
# Desafio
#
# 1. Promedio de area de todos los inmuebles en el top 10
#
# 2. Consultar otros daos estadisticos, conteo, mediana, valores minimo y maximo

# %%
#promedio total
promedio= inmuebles.Area.mean()
barrios =inmuebles.Barrio.value_counts()
print(barrios)

nombres_barrios = inmuebles['Barrio'].unique()
print(nombres_barrios)

inmuebles
# Out:
# Usaquén               1105
# Zona Noroccidental     877
# Bosa                   589
# Kennedy                589
# Cedritos               554
#                       ...
# Colinas De Suba          1
# La Estanzuela            1
# Roma                     1
# Alameda                  1
# Prado Veraniego          1
# Name: Barrio, Length: 149, dtype: int64
# ['Zona Noroccidental' 'Castilla' 'Chico Reservado' 'Usaquén' 'Bella Suiza'
#  'El Chicó' 'Tintala' 'Marly' 'Kennedy' 'Nicolas De Federman' 'La Calleja'
#  'Mazuren' 'Suba' 'Barrios Unidos' 'Engativa' 'Fontibón' 'Villa Alsacia'
#  'Palermo' 'La Candelaria' 'El Contador' 'El Batán' 'Santa Barbara'
#  'Mirandela ' 'Cedritos' 'Colina Campestre' 'Hayuelos' 'Ciudad Salitre'
#  'Quinta Paredes' 'Candelaria La Nueva' 'Chico Norte' 'Normandia'
#  'Ciudad Bolívar' 'Bosa' 'Rafael Uribe Uribe' 'Las Villas' 'Modelia'
#  'San Patricio' 'Barrancas' 'Teusaquillo' 'Puente Aranda' 'Chapinero'
# ...

# %%
import matplotlib.pyplot as plt

promedio_area_por_barrio = inmuebles.groupby('Barrio')['Area'].mean()
promedio_area_por_barrio.head(10).plot.bar()
top_10_promedio_area_por_barrio = promedio_area_por_barrio.nlargest(10)
top_10_promedio_area_por_barrio.plot.bar()
plt.title("El top 10 por Area/Barrio")
plt.xlabel('Barrio')
plt.ylabel('Promedio Area')
plt.show()

# %%
inmuebles.describe()
# Out:
#        Habitaciones        Banos           Area
# count   9520.000000  9520.000000    9520.000000
# mean       3.072479     2.447899     146.664706
# std        2.049856     1.255314    1731.379622
# min        1.000000     0.000000       2.000000
# 25%        2.000000     2.000000      57.000000
# 50%        3.000000     2.000000      80.000000
# 75%        3.000000     3.000000     135.000000
# max      110.000000     9.000000  166243.000000

# %%
promedio_area_por_barrio.describe()
# Out:
# count     149.000000
# mean      163.868114
# std       352.637815
# min        25.000000
# 25%        77.000000
# 50%       120.571429
# 75%       170.352941
# max      4316.750000
# Name: Area, dtype: float64

# %%
top_10_promedio_area_por_barrio.describe()
# Out:
# count      10.000000
# mean      762.011667
# std      1253.248239
# min       286.200000
# 25%       312.031250
# 50%       332.250000
# 75%       394.656250
# max      4316.750000
# Name: Area, dtype: float64

# %%
promedio_area_por_barrio
# Out:
# Barrio
# Alameda                97.000000
# Alhambra              190.411765
# Andes Norte           124.857143
# Antonio Nariño        163.062500
# Barrancas              70.200000
#                          ...
# Villa Maria           207.153846
# Villas De Granada      86.590909
# Villemar               76.888889
# Zona Franca            54.000000
# Zona Noroccidental    135.785633
# Name: Area, Length: 149, dtype: float64

# %% [markdown]
# Cortesia de una paria...
# Calcular el Promedio de Área de todos los inmuebles en los Barrios del dataset.
# Graficar el Top 10 de estos Promedios.

# %%
promedios_por_barrio = inmuebles.groupby('Barrio')['Area'].mean().reset_index()
'''
Al llamar a reset_index(), el índice actual se agrega como una columna en el DataFrame, y se restablece un índice numérico predeterminado.
Esto facilita el acceso a los datos y permite que el DataFrame tenga un formato más estándar con un índice numérico continuo.
'\nAl llamar a reset_index(), el índice actual se agrega como una columna en el DataFrame, y se restablece un índice numérico predeterminado.\nEsto facilita el acceso a los datos y permite que el DataFrame tenga un formato más estándar con un índice numérico continuo.\n'
'''
promedios_por_barrio
# Out:
#                  Barrio        Area
# 0               Alameda   97.000000
# 1              Alhambra  190.411765
# 2           Andes Norte  124.857143
# 3        Antonio Nariño  163.062500
# 4             Barrancas   70.200000
# ..                  ...         ...
# 144         Villa Maria  207.153846
# 145   Villas De Granada   86.590909
# 146            Villemar   76.888889
# 147         Zona Franca   54.000000
# 148  Zona Noroccidental  135.785633
#
# [149 rows x 2 columns]

# %%
# Gráfico del Top10 de Barrios
#se utilizo un metodo que ordene tomando como valor base el 'Area', luego se concatena con head(10) y esa forma se obtiene el top 10
top_10_promedios = promedios_por_barrio.sort_values(by='Area', ascending=False).head(10)
top_10_promedios
# Out:
#                     Barrio         Area
# 92                 Modelia  4316.750000
# 83              Libertador   642.000000
# 11           Bosa Piamonte   400.000000
# 73             La Soledad    378.625000
# 114               Restrepo   336.500000
# 127          Santa Librada   328.000000
# 80              Las Ferias   320.000000
# 124              Santa Ana   309.375000
# 141               Veraguas   302.666667
# 7    Bellavista Occidental   286.200000

# %%
# La librería Matplotlib se utiliza para personalizar y mostrar gráficos.
import matplotlib.pyplot as plt


top_10_promedios.plot(x='Barrio', y='Area', kind='bar', figsize=(10, 6), legend=False)
# Desactivar la leyenda automática, kind es el tipo de grafico, figsize() indica el tamaño del grafico

# Agregar etiquetas de ejes y título
plt.xlabel('Barrio')
plt.ylabel('Promedio de Área (m²)')
#agregar titulo
plt.title('Top 10 Promedios de Área por Barrio')
plt.legend(['Área Promedio'], fontsize=10)  # Agregar una leyenda personalizada

# %% [markdown]
# Calcular otros datos estadísticos. Ej: Conteo, Mediana, valores mínimo y máximo de cada uno de los atributos.
# ¿Cuál es la casa/apartamento más barato? ¿Cuál es el inmueble con mayor número de baños/habitaciones?

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   object
# dtypes: int64(3), object(5)
# memory usage: 595.1+ KB

# %% [markdown]
# #**Mediana**
# La mediana es el valor que se encuentra en el medio de un conjunto de datos cuando estos están ordenados en orden ascendente o descendente. En otras palabras, es el valor que divide al conjunto de datos en dos mitades iguales. Si tienes un número impar de datos, la mediana es el valor en el centro de la secuencia ordenada. Si tienes un número par de datos, la mediana es el promedio de los dos valores centrales. Sin embargo, Pandas tiene métodos incorporados para calcular la mediana de una columna sin necesidad de ordenar el dataset previamente. Puedes usar la función median() directamente en la columna que deseas analizar, y Pandas se encargará de calcular la mediana sin necesidad de ordenar manualmente el dataset.

# %%
# Mediana del número de habitaciones y baños
median_habitaciones = inmuebles['Habitaciones'].median()
print("Media de habitaciones: ",median_habitaciones)
mediana_banos = inmuebles['Banos'].median()
print("Media de baños: ",mediana_banos)
# Out:
# Media de habitaciones:  3.0
# Media de baños:  2.0

# %% [markdown]
# Para obtener el inmueble más barato y más costoso, dado que el campo "Valor" en el dataset es de tipo objeto y contiene el signo "$", primero debemos realizar algunas transformaciones en los datos para convertirlos a valores numéricos y luego identificar los inmuebles con los valores más bajos y más altos.

# %%
# Eliminar el signo "$" de la columna "Valor"
inmuebles['Valor'] = inmuebles['Valor'].str.replace('$', '')
# Eliminar el signo "." de la columna "Valor"
inmuebles['Valor'] = inmuebles['Valor'].str.replace('.', '')
# Convertir la columna "Valor" a valores numéricos
inmuebles['Valor'] = pd.to_numeric(inmuebles['Valor'])
inmuebles.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-60-5754df8c054b> in <cell line: 2>()
#       1 # Eliminar el signo "$" de la columna "Valor"
# ----> 2 inmuebles['Valor'] = inmuebles['Valor'].str.replace('$', '')
#       3 # Eliminar el signo "." de la columna "Valor"
#       4 inmuebles['Valor'] = inmuebles['Valor'].str.replace('.', '')
#       5 # Convertir la columna "Valor" a valores numéricos
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5900         ):
#    5901             return self[name]
# -> 5902         return object.__getattribute__(self, name)
#    5903
#    5904     def __setattr__(self, name: str, value) -> None:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     180             # we're accessing the attribute of the class, i.e., Dataset.geo
# ...

# %%
inmuebles.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9520 entries, 0 to 9519
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Tipo          9520 non-null   object
#  1   Descripcion   9520 non-null   object
#  2   Habitaciones  9520 non-null   int64
#  3   Banos         9520 non-null   int64
#  4   Area          9520 non-null   int64
#  5   Barrio        9520 non-null   object
#  6   UPZ           9478 non-null   object
#  7   Valor         9520 non-null   int64
# dtypes: int64(4), object(4)
# memory usage: 595.1+ KB

# %%
# Inmueble más costoso
indice_mas_costoso = inmuebles['Valor'].idxmax()
inmueble_mas_costoso = inmuebles.loc[indice_mas_costoso]
inmueble_mas_costoso
# Out:
# Tipo                                Edificio
# Descripcion     Edificio en venta en Usaquén
# Habitaciones                              12
# Banos                                      7
# Area                                    1664
# Barrio                               Usaquén
# UPZ                                  Usaquén
# Valor                            16000000000
# Name: 5234, dtype: object

# %%
# Inmueble más barato
indice_mas_barato = inmuebles['Valor'].idxmin()
inmueble_mas_barato = inmuebles.loc[indice_mas_barato]
inmueble_mas_barato
# Out:
# Tipo                                      Oficina/Consultorio
# Descripcion     Oficina/Consultorio en venta en La Candelaria
# Habitaciones                                                1
# Banos                                                       2
# Area                                                       24
# Barrio                                          La Candelaria
# UPZ                                             La Candelaria
# Valor                                                60000000
# Name: 4847, dtype: object

# %% [markdown]
# #Valores Mínimos y Máximos
# Para obtener el inmueble con el mayor y menor número de baños o habitaciones en tu dataset de inmuebles en Pandas, puedes utilizar las funciones idxmax() y idxmin() para encontrar los índices de las filas que tienen los valores máximos y mínimos en las columnas respectivas.

# %%
# Inmueble con mayor numero de habitaciones
#obtener el indice
indice_max_habitaciones = inmuebles['Habitaciones'].idxmax()

#acceder al registro con ese indice a traves de loc
inmueble_max_habitaciones = inmuebles.loc[indice_max_habitaciones]
inmueble_max_habitaciones

#tambien se puede haber en menos lineas
#inmueble_max_habitaciones = inmuebles.loc[inmuebles['Habitaciones'].idxmax()]
# Out:
# Tipo                                 Casa
# Descripcion     Casa en venta en La Uribe
# Habitaciones                          110
# Banos                                   2
# Area                                  110
# Barrio                           La Uribe
# UPZ                               Usaquén
# Valor                           480000000
# Name: 897, dtype: object

# %%
# Inmueble con menor número de habitaciones
#primer paso el indice
indice_min_habitaciones = inmuebles['Habitaciones'].idxmin()
#acceder al registro
inmueble_min_habitaciones = inmuebles.loc[indice_min_habitaciones]
print(inmueble_min_habitaciones)
# Out:
# Tipo                                      Apartamento
# Descripcion       Apartamento en venta en Bella Suiza
# Habitaciones                                        1
# Banos                                               2
# Area                                               62
# Barrio                                    Bella Suiza
# UPZ             USAQUÉN: Country Club + Santa Bárbara
# Valor                                       510000000
# Name: 5, dtype: object

# %%
# Inmueble con mayor número de baños
#buscar el indice
indice_max_banos = inmuebles['Banos'].idxmax()
# valor devuelto 1955

#acceso al registro
inmueble_max_banos = inmuebles.iloc[indice_max_banos]
inmueble_max_banos
# Out:
# Tipo                                         Local
# Descripcion       Local en venta en Quinta Camacho
# Habitaciones                                    16
# Banos                                            9
# Area                                          1050
# Barrio                              Quinta Camacho
# UPZ             CHAPINERO: Chicó Lago + El Refugio
# Valor                                   5299999744
# Name: 1955, dtype: object

# %%
# Inmueble con menor número de baños
#bucar el indice
indice_min_banos = inmuebles['Banos'].idxmin()
indice_min_banos
# valor devuelto 2910

#acceso al registro
inmueble_min_banos = inmuebles.iloc[indice_min_banos]
inmueble_min_banos
# Out:
# Tipo                                         Edificio
# Descripcion        Edificio en venta en Santa Barbara
# Habitaciones                                       22
# Banos                                               0
# Area                                             1080
# Barrio                                  Santa Barbara
# UPZ             USAQUÉN: Country Club + Santa Bárbara
# Valor                                      9200000000
# Name: 2910, dtype: object

# %%
#ahora añado graficos por cantidad de habitaciones
viviendas_por_banos = inmuebles['Banos'].value_counts().reset_index()
viviendas_por_banos.sort_values(by='index', ascending=False).plot(kind='bar', legend=False, color='green')

plt.legend(['Cantidad de viviendas por cantidad de baños'])
plt.show()

# %%
#ahora añado graficos por cantidad de habitaciones

viviendas_por_habitaciones = inmuebles['Habitaciones'].value_counts().reset_index()
viviendas_por_habitaciones.sort_values(by='index', ascending=False).plot(kind='bar', legend=False, color='green')

plt.legend(['Cantidad de viviendas por cantidad de Habitaciones'])
plt.show()
