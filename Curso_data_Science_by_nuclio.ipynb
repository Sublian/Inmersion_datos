# %% [markdown]
# <a href="https://colab.research.google.com/github/Sublian/Inmersion_datos/blob/main/Curso_data_Science_by_nuclio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Inicializando el Google Drive (sincronizando)

# %%
#con estos comandos podemos utilizar el archivo que tenemos en nuestro drive
#si no usaras un archivo en tu Drive saltar este paso
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# #Importacion de la DB Titanic

# %%
#importamos la libreria pandas
import pandas as pd

#en mi caso subi el archivo del titanic desde mi drive por ello la ruta del archivo es asi
df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/analisis/titanic.csv")

#hago una muestra
df.sample(5)
# Out:
#      PassengerId  Survived  Pclass                            Name     Sex  \
# 702          703         0       3           Barbara, Miss. Saiide  female
# 179          180         0       3             Leonard, Mr. Lionel    male
# 612          613         1       3     Murphy, Miss. Margaret Jane  female
# 104          105         0       3  Gustafsson, Mr. Anders Vilhelm    male
# 687          688         0       3               Dakic, Mr. Branko    male
#
#       Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 702  18.0      0      1     2691  14.4542   NaN        C
# 179  36.0      0      0     LINE   0.0000   NaN        S
# 612   NaN      1      0   367230  15.5000   NaN        Q
# 104  37.0      2      0  3101276   7.9250   NaN        S
# 687  19.0      0      0   349228  10.1708   NaN        S

# %% [markdown]
# **Problema 1**
# Establece el nombre del pasajero como indice de las filas y muestra los 10  primeros registros de la base de datos. Guarda este nuevo DF como "Data"

# %%
#solucion problema 1
data=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/analisis/titanic.csv", index_col=3)
data.head(10)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Braund, Mr. Owen Harris                                       1         0
# Cumings, Mrs. John Bradley (Florence Briggs Tha...            2         1
# Heikkinen, Miss. Laina                                        3         1
# Futrelle, Mrs. Jacques Heath (Lily May Peel)                  4         1
# Allen, Mr. William Henry                                      5         0
# Moran, Mr. James                                              6         0
# McCarthy, Mr. Timothy J                                       7         0
# Palsson, Master. Gosta Leonard                                8         0
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)             9         1
# Nasser, Mrs. Nicholas (Adele Achem)                          10         1
#
#                                                     Pclass     Sex   Age  \
# Name
# ...

# %% [markdown]
# ##Conociendo los elementos del DataFrame

# %%
#para el primer acercamiento usamos info()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
#para conocer la cantidad de elementos y columnas de forma numerica podemos usar shape. Que retorna la cantidad de filas y la cantidad de columnas
df.shape
# Out:
# (891, 12)

# %%
#para conocer el numero de elementos usaremos size
df.size
# Out:
# 10692

# %% [markdown]
# #Renombrar y acceder al DataFrame
#
# En este momento necesitamos cambiar el nombre de la columna "Fare" por "Ticket Prize"

# %%
df.rename(columns={"Fare":"Ticket Price"})
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Ejercicios de acceso de indices

# %%
#accediendo desde posicion
df.iloc[3]
df.iloc[5,3]
df.iloc[-1,3:6]
# Out:
# Name    Dooley, Mr. Patrick
# Sex                    male
# Age                    32.0
# Name: 890, dtype: object

# %%
#accediendo desde una etiqueta
df.loc[3, "Name"]
df.loc[3, ["Name","Sex", "Age"]]
# Out:
# Name    Futrelle, Mrs. Jacques Heath (Lily May Peel)
# Sex                                           female
# Age                                             35.0
# Name: 3, dtype: object

# %% [markdown]
# Creacion de un DF con los nombres de los pasajeros, sexo y edad

# %%
data1=df.loc[:,["Name", "Sex", "Age"]]
data1
# Out:
#                                                   Name     Sex   Age
# 0                              Braund, Mr. Owen Harris    male  22.0
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 2                               Heikkinen, Miss. Laina  female  26.0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 4                             Allen, Mr. William Henry    male  35.0
# ..                                                 ...     ...   ...
# 886                              Montvila, Rev. Juozas    male  27.0
# 887                       Graham, Miss. Margaret Edith  female  19.0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN
# 889                              Behr, Mr. Karl Howell    male  26.0
# 890                                Dooley, Mr. Patrick    male  32.0
#
# [891 rows x 3 columns]

# %% [markdown]
# Crear un dataframe con los primeros 5 registros

# %%
data2= df.loc[:4,:]
data2
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# **Problema 2**
# Dividir el dataframe del Titanic en dos, con el mismo numero de registros cada uno

# %%
#primero debemos de conocer el tamaño del dataframe, para ello haremos lo siguiente
df.shape[0]/2
# Out:
# 445.5

# %%
df1=df.iloc[:445,:]
df1
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 440          441         1       2
# 441          442         0       3
# 442          443         0       3
# 443          444         1       2
# 444          445         1       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
df2=df.iloc[445:,:]
df2
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 445          446         1       1                 Dodge, Master. Washington
# 446          447         1       2         Mellinger, Miss. Madeleine Violet
# 447          448         1       1               Seward, Mr. Frederic Kimber
# 448          449         1       3            Baclini, Miss. Marie Catherine
# 449          450         1       1            Peuchen, Major. Arthur Godfrey
# ..           ...       ...     ...                                       ...
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# #Opciones para las columnas
#
# Eliminar columnas

# %%
df2.pop("SibSp")
# Out:
# 445    0
# 446    0
# 447    0
# 448    2
# 449    0
#       ..
# 886    0
# 887    0
# 888    1
# 889    0
# 890    0
# Name: SibSp, Length: 446, dtype: int64

# %% [markdown]
# Añadir columnas. Por ejemplo añadir precio del ticket por edad

# %%
df["Price/Age"]=df["Fare"]/df["Age"]
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# #Analisis descriptivo
# Contar las filas no NaN

# %%
df.count()
# Out:
# PassengerId    891
# Survived       891
# Pclass         891
# Name           891
# Sex            891
# Age            714
# SibSp          891
# Parch          891
# Ticket         891
# Fare           891
# Cabin          204
# Embarked       889
# Price/Age      714
# dtype: int64

# %% [markdown]
# Cuantas persoinas han sobrevivido?

# %%
df["Survived"].sum()
# Out:
# 342

# %% [markdown]
# Suma acumulada de supervivientes?

# %%
df["Survived"].cumsum()
# Out:
# 0        0
# 1        1
# 2        2
# 3        3
# 4        3
#       ...
# 886    340
# 887    341
# 888    341
# 889    342
# 890    342
# Name: Survived, Length: 891, dtype: int64

# %% [markdown]
# Maximo y minimo de edad

# %%
df["Age"].min()
# Out:
# 0.42

# %%
df["Age"].max()
# Out:
# 80.0

# %%
df.max()
# Out:
# <ipython-input-29-4c1ddf8920ff>:1: FutureWarning: The default value of numeric_only in DataFrame.max is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.max()
# PassengerId                            891
# Survived                                 1
# Pclass                                   3
# Name           van Melkebeke, Mr. Philemon
# Sex                                   male
# Age                                   80.0
# SibSp                                    8
# Parch                                    6
# Ticket                           WE/P 5735
# Fare                              512.3292
# Price/Age                       164.728261
# dtype: object

# %% [markdown]
# Resumen estadistico del Dataframe

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare   Price/Age
# count  891.000000  891.000000  714.000000
# mean     0.381594   32.204208    2.391841
# std      0.806057   49.693429    8.115102
# min      0.000000    0.000000    0.000000
# 25%      0.000000    7.910400    0.342403
# 50%      0.000000   14.454200    0.565217
# 75%      0.000000   31.000000    1.673857
# ...

# %% [markdown]
# **Problema 3**
# Calcular la tarifa media de los pasajeros del Titanic y crea una nueva columna llamada "Fare/Mean Fare" donde calcules el ratio entre la tarifa que ha pagado cada pasajero entre la tarifa media

# %%
mean_fare=df["Fare"].mean()
mean_fare
# Out:
# 32.204207968574636

# %%
df["Fare/Mean Fare"]=df["Fare"]/mean_fare
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Problema 4**
#
# Muestra el precio mas elevado y el precio mas bajo del ticket para el Titanic. Tambien muestra la recaudacion total por la venta de tickets

# %%
print(f"El precio minimo costo: {df['Fare'].min()}$")
print(f"El precio maximo costo: {df['Fare'].max()}$" )
print(f"La recaudacion total de tickets fue de: {round(df['Fare'].sum(),2)}$")
# Out:
# El precio minimo costo: 0.0$
# El precio maximo costo: 512.3292$
# La recaudacion total de tickets fue de: 28693.95$

# %% [markdown]
# #**Filtrado de filas**
# Cual es el registro del boleto de la persona mas anciana en el Titanic

# %%
df[(df["Age"]==df["Age"].max())]
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 630          631         1       1  Barkworth, Mr. Algernon Henry Wilson
#
#       Sex   Age  SibSp  Parch Ticket  Fare Cabin Embarked  Price/Age  \
# 630  male  80.0      0      0  27042  30.0   A23        S      0.375
#
#      Fare/Mean Fare
# 630        0.931555

# %% [markdown]
# Muestra a los pasajeros que sobrevivieron que sean mayores a 60 años

# %%
df[(df["Age"]>60) & (df["Survived"]==1)]
# Out:
#      PassengerId  Survived  Pclass                                       Name  \
# 275          276         1       1          Andrews, Miss. Kornelia Theodosia
# 483          484         1       3                     Turkula, Mrs. (Hedwig)
# 570          571         1       2                         Harris, Mr. George
# 630          631         1       1       Barkworth, Mr. Algernon Henry Wilson
# 829          830         1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch       Ticket     Fare Cabin Embarked  \
# 275  female  63.0      1      0        13502  77.9583    D7        S
# 483  female  63.0      0      0         4134   9.5875   NaN        S
# 570    male  62.0      0      0  S.W./PP 752  10.5000   NaN        S
# 630    male  80.0      0      0        27042  30.0000   A23        S
# 829  female  62.0      0      0       113572  80.0000   B28      NaN
#
#      Price/Age  Fare/Mean Fare
# 275   1.237433        2.420749
# ...

# %% [markdown]
# Muestra a los pasajeros con algun familiar abordo y no sobrevivieron

# %%
df[((df["SibSp"]>0)|(df["Parch"]!=0))&(df["Survived"]==0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 7              8         0       3
# 13            14         0       3
# 16            17         0       3
# 18            19         0       3
# ..           ...       ...     ...
# 860          861         0       3
# 861          862         0       2
# 863          864         0       3
# 885          886         0       3
# 888          889         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 7                       Palsson, Master. Gosta Leonard    male   2.0      3
# 13                         Andersson, Mr. Anders Johan    male  39.0      1
# 16                                Rice, Master. Eugene    male   2.0      4
# 18   Vander Planke, Mrs. Julius (Emelia Maria Vande...  female  31.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# Muestra un dataframe solo con columnas que terminen en la letra "e"

# %%
df.filter(regex="e$", axis=1)
# Out:
#                                                   Name   Age     Fare  \
# 0                              Braund, Mr. Owen Harris  22.0   7.2500
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  38.0  71.2833
# 2                               Heikkinen, Miss. Laina  26.0   7.9250
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  35.0  53.1000
# 4                             Allen, Mr. William Henry  35.0   8.0500
# ..                                                 ...   ...      ...
# 886                              Montvila, Rev. Juozas  27.0  13.0000
# 887                       Graham, Miss. Margaret Edith  19.0  30.0000
# 888           Johnston, Miss. Catherine Helen "Carrie"   NaN  23.4500
# 889                              Behr, Mr. Karl Howell  26.0  30.0000
# 890                                Dooley, Mr. Patrick  32.0   7.7500
#
#      Price/Age  Fare/Mean Fare
# 0     0.329545        0.225126
# 1     1.875876        2.213478
# ...

# %% [markdown]
# Muestra un Dataframe con "Mary" en el nombre.

# %%
data.filter(like="Mary", axis=0)
# Out:
#                                                     PassengerId  Survived  \
# Name
# Hewlett, Mrs. (Mary D Kingcome)                              16         1
# Glynn, Miss. Mary Agatha                                     33         1
# Wick, Miss. Mary Natalie                                    319         1
# Slayter, Miss. Hilda Mary                                   323         1
# Davison, Mrs. Thomas Henry (Mary E Finck)                   348         1
# McGovern, Miss. Mary                                        359         1
# Mockler, Miss. Helen Mary "Ellie"                           360         1
# Nakid, Miss. Maria ("Mary")                                 382         1
# Holverson, Mrs. Alexander Oskar (Mary Aline Tow...          384         1
# West, Mrs. Edwy Arthur (Ada Mary Worth)                     473         1
# Canavan, Miss. Mary                                         502         0
# O'Sullivan, Miss. Bridget Mary                              503         0
# ...

# %% [markdown]
# **Problema 5**
#
# Cuantos pasajeros pagaron mas de la media y sobrevivieron

# %%
df[(df["Fare"]>df["Fare"].mean())&(df["Survived"]==1)]
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 23            24         1       1
# 31            32         1       1
# 43            44         1       2
# ..           ...       ...     ...
# 849          850         1       1
# 853          854         1       1
# 856          857         1       1
# 871          872         1       1
# 879          880         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# 31      Spencer, Mrs. William Augustus (Marie Eugenie)  female   NaN      1
# 43            Laroche, Miss. Simonne Marie Anne Andree  female   3.0      1
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# **Problema 6**
#
# Crea un dataframe que contenga todas las columnas que comiencen por la letra "A"

# %%
df.filter(regex="^A", axis=1)
# Out:
#       Age
# 0    22.0
# 1    38.0
# 2    26.0
# 3    35.0
# 4    35.0
# ..    ...
# 886  27.0
# 887  19.0
# 888   NaN
# 889  26.0
# 890  32.0
#
# [891 rows x 1 columns]
